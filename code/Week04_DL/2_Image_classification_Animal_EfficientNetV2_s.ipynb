# %% [markdown]
# # Image classificartion with EfficientNetV2s
# <br>Last updated on 23/01/2024 by TA.Pete</br>
# <br>Objective: We aim to classify images into 10 classes of custom animal dataset using EfficientNetV2s</br>
# credit:<br>
# https://pytorch.org/tutorials/beginner/data_loading_tutorial.html<br>
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html<br>
# https://www.kaggle.com/datasets/alessiocorrado99/animals10<br>

# %%
! nvidia-smi
# Out:
# Sat Jan 20 04:48:39 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# Download dataset

# %%
# !wget https://github.com/pvateekul/2110531_DSDE_2023s1/raw/main/code/Week05_Intro_Deep_Learning/data/Dataset_animal2.zip
# Out:
# --2024-01-20 04:48:39--  https://github.com/pvateekul/2110531_DSDE_2023s1/raw/main/code/Week05_Intro_Deep_Learning/data/Dataset_animal2.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/pvateekul/2110531_DSDE_2023s1/main/code/Week05_Intro_Deep_Learning/data/Dataset_animal2.zip [following]
# --2024-01-20 04:48:39--  https://media.githubusercontent.com/media/pvateekul/2110531_DSDE_2023s1/main/code/Week05_Intro_Deep_Learning/data/Dataset_animal2.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29663352 (28M) [application/zip]
# Saving to: ‘Dataset_animal2.zip’
#
# Dataset_animal2.zip 100%[===================>]  28.29M   171MB/s    in 0.2s
#
# 2024-01-20 04:48:40 (171 MB/s) - ‘Dataset_animal2.zip’ saved [29663352/29663352]

# %%
# !unzip -q -o 'Dataset_animal2.zip'

# %%
from sklearn.exceptions import UndefinedMetricWarning

def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from PIL import Image
import os

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

transform_train = transforms.Compose(
    [transforms.Resize((230,230)),
        transforms.RandomRotation(30,),
        transforms.RandomCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.507, 0.487, 0.441], std=[0.267, 0.256, 0.276]) #nomalize imagenet pretrain
    ])

transform = transforms.Compose(
    [transforms.Resize((224,224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.507, 0.487, 0.441], std=[0.267, 0.256, 0.276])
    ])

batch_size = 32

# %%
class AnimalDataset(Dataset):

    def __init__(self,
                 img_dir,
                 transforms=None):

        super().__init__()
        label_image = ['butterfly','cat','chicken','cow','dog','elephant','horse','sheep','spider','squirrel']
        self.input_dataset = list()
        label_num = 0
        for label in label_image:
            _, _, files = next(os.walk(os.path.join(img_dir,label)))
            for image_name in files:
                input = [os.path.join(img_dir,label,image_name),label_num] # [image_path, label_num]
                self.input_dataset.append(input)
            label_num += 1

        self.transforms = transforms

    def __len__(self):
        return len(self.input_dataset)

    def __getitem__(self, idx):
        img = Image.open(self.input_dataset[idx][0]).convert('RGB')
        x = self.transforms(img)
        y = self.input_dataset[idx][1]
        return x,y

trainset = AnimalDataset('./Dataset_animal2/train',transform_train)
valset = AnimalDataset('./Dataset_animal2/val',transform)
testset = AnimalDataset('./Dataset_animal2/test',transform)


trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=True)

#classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
trainset.__len__(), valset.__len__(), testset.__len__()
# Out:
# (1400, 300, 300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image
def imshow(img):
    img = img*torch.tensor([0.267, 0.256, 0.276]).mean() + torch.tensor([0.507, 0.487, 0.441]).mean()     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(16,16))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
nrow = 9
imshow(torchvision.utils.make_grid(images, nrow = nrow))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# print labels
for i in range(batch_size//nrow + 1 if batch_size % nrow else 0):
  print(' '.join(f'{labels[i*nrow+j]:<3}' for j in range(min(batch_size - i*nrow, nrow))))
# Out:
# 0   6   5   7   3   3   3   5   1
# 6   8   1   2   9   5   1   6   0
# 1   8   0   7   7   8   8   5   5
# 0   2   5   1   9

# %%
import torch.nn as nn
import torch.nn.functional as F

pretrain_weight = torchvision.models.EfficientNet_V2_S_Weights.IMAGENET1K_V1
net = torchvision.models.efficientnet_v2_s(weights = pretrain_weight)
net.classifier[1] = nn.Linear(1280, 10)
net = net.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_s-dd5fe13b.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2_s-dd5fe13b.pth
# 100%|██████████| 82.7M/82.7M [00:01<00:00, 69.7MB/s]

# %%
from torchsummary import summary
summary(net, (3, 224, 224), batch_size = 64)
#from torchinfo import summary as summary_info
#summary_info(net, input_size = (128, 3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [64, 24, 112, 112]             648
#        BatchNorm2d-2         [64, 24, 112, 112]              48
#               SiLU-3         [64, 24, 112, 112]               0
#             Conv2d-4         [64, 24, 112, 112]           5,184
#        BatchNorm2d-5         [64, 24, 112, 112]              48
#               SiLU-6         [64, 24, 112, 112]               0
#    StochasticDepth-7         [64, 24, 112, 112]               0
#        FusedMBConv-8         [64, 24, 112, 112]               0
#             Conv2d-9         [64, 24, 112, 112]           5,184
#       BatchNorm2d-10         [64, 24, 112, 112]              48
#              SiLU-11         [64, 24, 112, 112]               0
#   StochasticDepth-12         [64, 24, 112, 112]               0
#       FusedMBConv-13         [64, 24, 112, 112]               0
#            Conv2d-14           [64, 96, 56, 56]          20,736
#       BatchNorm2d-15           [64, 96, 56, 56]             192
#              SiLU-16           [64, 96, 56, 56]               0
#            Conv2d-17           [64, 48, 56, 56]           4,608
#       BatchNorm2d-18           [64, 48, 56, 56]              96
#       FusedMBConv-19           [64, 48, 56, 56]               0
#            Conv2d-20          [64, 192, 56, 56]          82,944
#       BatchNorm2d-21          [64, 192, 56, 56]             384
#              SiLU-22          [64, 192, 56, 56]               0
#            Conv2d-23           [64, 48, 56, 56]           9,216
#       BatchNorm2d-24           [64, 48, 56, 56]              96
#   StochasticDepth-25           [64, 48, 56, 56]               0
#       FusedMBConv-26           [64, 48, 56, 56]               0
#            Conv2d-27          [64, 192, 56, 56]          82,944
#       BatchNorm2d-28          [64, 192, 56, 56]             384
#              SiLU-29          [64, 192, 56, 56]               0
#            Conv2d-30           [64, 48, 56, 56]           9,216
#       BatchNorm2d-31           [64, 48, 56, 56]              96
#   StochasticDepth-32           [64, 48, 56, 56]               0
#       FusedMBConv-33           [64, 48, 56, 56]               0
#            Conv2d-34          [64, 192, 56, 56]          82,944
#       BatchNorm2d-35          [64, 192, 56, 56]             384
#              SiLU-36          [64, 192, 56, 56]               0
#            Conv2d-37           [64, 48, 56, 56]           9,216
#       BatchNorm2d-38           [64, 48, 56, 56]              96
#   StochasticDepth-39           [64, 48, 56, 56]               0
#       FusedMBConv-40           [64, 48, 56, 56]               0
#            Conv2d-41          [64, 192, 28, 28]          82,944
#       BatchNorm2d-42          [64, 192, 28, 28]             384
#              SiLU-43          [64, 192, 28, 28]               0
#            Conv2d-44           [64, 64, 28, 28]          12,288
#       BatchNorm2d-45           [64, 64, 28, 28]             128
#       FusedMBConv-46           [64, 64, 28, 28]               0
#            Conv2d-47          [64, 256, 28, 28]         147,456
#       BatchNorm2d-48          [64, 256, 28, 28]             512
#              SiLU-49          [64, 256, 28, 28]               0
#            Conv2d-50           [64, 64, 28, 28]          16,384
#           Conv2d-229          [64, 960, 14, 14]           8,640
#      BatchNorm2d-230          [64, 960, 14, 14]           1,920
#             SiLU-231          [64, 960, 14, 14]               0
# AdaptiveAvgPool2d-232            [64, 960, 1, 1]               0
#           Conv2d-233             [64, 40, 1, 1]          38,440
#             SiLU-234             [64, 40, 1, 1]               0
#           Conv2d-235            [64, 960, 1, 1]          39,360
#          Sigmoid-236            [64, 960, 1, 1]               0
# SqueezeExcitation-237          [64, 960, 14, 14]               0
#           Conv2d-238          [64, 160, 14, 14]         153,600
#      BatchNorm2d-239          [64, 160, 14, 14]             320
#  StochasticDepth-240          [64, 160, 14, 14]               0
#           MBConv-241          [64, 160, 14, 14]               0
#           Conv2d-242          [64, 960, 14, 14]         153,600
#      BatchNorm2d-243          [64, 960, 14, 14]           1,920
#             SiLU-244          [64, 960, 14, 14]               0
#           Conv2d-245          [64, 960, 14, 14]           8,640
#      BatchNorm2d-246          [64, 960, 14, 14]           1,920
#             SiLU-247          [64, 960, 14, 14]               0
# AdaptiveAvgPool2d-248            [64, 960, 1, 1]               0
#           Conv2d-249             [64, 40, 1, 1]          38,440
#             SiLU-250             [64, 40, 1, 1]               0
#           Conv2d-251            [64, 960, 1, 1]          39,360
#          Sigmoid-252            [64, 960, 1, 1]               0
# SqueezeExcitation-253          [64, 960, 14, 14]               0
#           Conv2d-254          [64, 160, 14, 14]         153,600
#      BatchNorm2d-255          [64, 160, 14, 14]             320
#  StochasticDepth-256          [64, 160, 14, 14]               0
#           MBConv-257          [64, 160, 14, 14]               0
#           Conv2d-258          [64, 960, 14, 14]         153,600
#      BatchNorm2d-259          [64, 960, 14, 14]           1,920
#             SiLU-260          [64, 960, 14, 14]               0
#           Conv2d-261          [64, 960, 14, 14]           8,640
#      BatchNorm2d-262          [64, 960, 14, 14]           1,920
#             SiLU-263          [64, 960, 14, 14]               0
# AdaptiveAvgPool2d-264            [64, 960, 1, 1]               0
#           Conv2d-265             [64, 40, 1, 1]          38,440
#             SiLU-266             [64, 40, 1, 1]               0
#           Conv2d-267            [64, 960, 1, 1]          39,360
#          Sigmoid-268            [64, 960, 1, 1]               0
# SqueezeExcitation-269          [64, 960, 14, 14]               0
#           Conv2d-270          [64, 160, 14, 14]         153,600
#      BatchNorm2d-271          [64, 160, 14, 14]             320
#  StochasticDepth-272          [64, 160, 14, 14]               0
#           MBConv-273          [64, 160, 14, 14]               0
#           Conv2d-274          [64, 960, 14, 14]         153,600
#      BatchNorm2d-275          [64, 960, 14, 14]           1,920
#             SiLU-276          [64, 960, 14, 14]               0
#           Conv2d-277          [64, 960, 14, 14]           8,640
#      BatchNorm2d-278          [64, 960, 14, 14]           1,920
#             SiLU-279          [64, 960, 14, 14]               0
# AdaptiveAvgPool2d-280            [64, 960, 1, 1]               0
#           Conv2d-281             [64, 40, 1, 1]          38,440
#             SiLU-282             [64, 40, 1, 1]               0
#           Conv2d-283            [64, 960, 1, 1]          39,360
#          Sigmoid-284            [64, 960, 1, 1]               0
# SqueezeExcitation-285          [64, 960, 14, 14]               0
#           Conv2d-286          [64, 160, 14, 14]         153,600
#      BatchNorm2d-287          [64, 160, 14, 14]             320
#  StochasticDepth-288          [64, 160, 14, 14]               0
#           MBConv-289          [64, 160, 14, 14]               0
#           Conv2d-290          [64, 960, 14, 14]         153,600
#      BatchNorm2d-291          [64, 960, 14, 14]           1,920
#             SiLU-292          [64, 960, 14, 14]               0
#           Conv2d-293          [64, 960, 14, 14]           8,640
#      BatchNorm2d-294          [64, 960, 14, 14]           1,920
#             SiLU-295          [64, 960, 14, 14]               0
# AdaptiveAvgPool2d-296            [64, 960, 1, 1]               0
#           Conv2d-297             [64, 40, 1, 1]          38,440
#             SiLU-298             [64, 40, 1, 1]               0
#           Conv2d-299            [64, 960, 1, 1]          39,360
#          Sigmoid-300            [64, 960, 1, 1]               0
# SqueezeExcitation-301          [64, 960, 14, 14]               0
#           Conv2d-302          [64, 160, 14, 14]         153,600
#      BatchNorm2d-303          [64, 160, 14, 14]             320
#  StochasticDepth-304          [64, 160, 14, 14]               0
#           MBConv-305          [64, 160, 14, 14]               0
#           Conv2d-306          [64, 960, 14, 14]         153,600
#      BatchNorm2d-307          [64, 960, 14, 14]           1,920
#             SiLU-308          [64, 960, 14, 14]               0
#           Conv2d-309            [64, 960, 7, 7]           8,640
#      BatchNorm2d-310            [64, 960, 7, 7]           1,920
#             SiLU-311            [64, 960, 7, 7]               0
# AdaptiveAvgPool2d-312            [64, 960, 1, 1]               0
#           Conv2d-313             [64, 40, 1, 1]          38,440
#             SiLU-314             [64, 40, 1, 1]               0
#           Conv2d-315            [64, 960, 1, 1]          39,360
#          Sigmoid-316            [64, 960, 1, 1]               0
# SqueezeExcitation-317            [64, 960, 7, 7]               0
#           Conv2d-318            [64, 256, 7, 7]         245,760
#      BatchNorm2d-319            [64, 256, 7, 7]             512
#           MBConv-320            [64, 256, 7, 7]               0
#           Conv2d-321           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-322           [64, 1536, 7, 7]           3,072
#             SiLU-323           [64, 1536, 7, 7]               0
#           Conv2d-324           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-325           [64, 1536, 7, 7]           3,072
#             SiLU-326           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-327           [64, 1536, 1, 1]               0
#           Conv2d-328             [64, 64, 1, 1]          98,368
#             SiLU-329             [64, 64, 1, 1]               0
#           Conv2d-330           [64, 1536, 1, 1]          99,840
#          Sigmoid-331           [64, 1536, 1, 1]               0
# SqueezeExcitation-332           [64, 1536, 7, 7]               0
#           Conv2d-333            [64, 256, 7, 7]         393,216
#      BatchNorm2d-334            [64, 256, 7, 7]             512
#  StochasticDepth-335            [64, 256, 7, 7]               0
#           MBConv-336            [64, 256, 7, 7]               0
#           Conv2d-337           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-338           [64, 1536, 7, 7]           3,072
#             SiLU-339           [64, 1536, 7, 7]               0
#           Conv2d-340           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-341           [64, 1536, 7, 7]           3,072
#             SiLU-342           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-343           [64, 1536, 1, 1]               0
#           Conv2d-344             [64, 64, 1, 1]          98,368
#             SiLU-345             [64, 64, 1, 1]               0
#           Conv2d-346           [64, 1536, 1, 1]          99,840
#          Sigmoid-347           [64, 1536, 1, 1]               0
# SqueezeExcitation-348           [64, 1536, 7, 7]               0
#           Conv2d-349            [64, 256, 7, 7]         393,216
#      BatchNorm2d-350            [64, 256, 7, 7]             512
#  StochasticDepth-351            [64, 256, 7, 7]               0
#           MBConv-352            [64, 256, 7, 7]               0
#           Conv2d-353           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-354           [64, 1536, 7, 7]           3,072
#             SiLU-355           [64, 1536, 7, 7]               0
#           Conv2d-356           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-357           [64, 1536, 7, 7]           3,072
#             SiLU-358           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-359           [64, 1536, 1, 1]               0
#           Conv2d-360             [64, 64, 1, 1]          98,368
#             SiLU-361             [64, 64, 1, 1]               0
#           Conv2d-362           [64, 1536, 1, 1]          99,840
#          Sigmoid-363           [64, 1536, 1, 1]               0
# SqueezeExcitation-364           [64, 1536, 7, 7]               0
#           Conv2d-365            [64, 256, 7, 7]         393,216
#      BatchNorm2d-366            [64, 256, 7, 7]             512
#  StochasticDepth-367            [64, 256, 7, 7]               0
#           MBConv-368            [64, 256, 7, 7]               0
#           Conv2d-369           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-370           [64, 1536, 7, 7]           3,072
#             SiLU-371           [64, 1536, 7, 7]               0
#           Conv2d-372           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-373           [64, 1536, 7, 7]           3,072
#             SiLU-374           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-375           [64, 1536, 1, 1]               0
#           Conv2d-376             [64, 64, 1, 1]          98,368
#             SiLU-377             [64, 64, 1, 1]               0
#           Conv2d-378           [64, 1536, 1, 1]          99,840
#          Sigmoid-379           [64, 1536, 1, 1]               0
# SqueezeExcitation-380           [64, 1536, 7, 7]               0
#           Conv2d-381            [64, 256, 7, 7]         393,216
#      BatchNorm2d-382            [64, 256, 7, 7]             512
#  StochasticDepth-383            [64, 256, 7, 7]               0
#           MBConv-384            [64, 256, 7, 7]               0
#           Conv2d-385           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-386           [64, 1536, 7, 7]           3,072
#             SiLU-387           [64, 1536, 7, 7]               0
#           Conv2d-388           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-389           [64, 1536, 7, 7]           3,072
#             SiLU-390           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-391           [64, 1536, 1, 1]               0
#           Conv2d-392             [64, 64, 1, 1]          98,368
#             SiLU-393             [64, 64, 1, 1]               0
#           Conv2d-394           [64, 1536, 1, 1]          99,840
#          Sigmoid-395           [64, 1536, 1, 1]               0
# SqueezeExcitation-396           [64, 1536, 7, 7]               0
#           Conv2d-397            [64, 256, 7, 7]         393,216
#      BatchNorm2d-398            [64, 256, 7, 7]             512
#  StochasticDepth-399            [64, 256, 7, 7]               0
#           MBConv-400            [64, 256, 7, 7]               0
#           Conv2d-401           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-402           [64, 1536, 7, 7]           3,072
#             SiLU-403           [64, 1536, 7, 7]               0
#           Conv2d-404           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-405           [64, 1536, 7, 7]           3,072
#             SiLU-406           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-407           [64, 1536, 1, 1]               0
#           Conv2d-408             [64, 64, 1, 1]          98,368
#             SiLU-409             [64, 64, 1, 1]               0
#           Conv2d-410           [64, 1536, 1, 1]          99,840
#          Sigmoid-411           [64, 1536, 1, 1]               0
# SqueezeExcitation-412           [64, 1536, 7, 7]               0
#           Conv2d-413            [64, 256, 7, 7]         393,216
#      BatchNorm2d-414            [64, 256, 7, 7]             512
#  StochasticDepth-415            [64, 256, 7, 7]               0
#           MBConv-416            [64, 256, 7, 7]               0
#           Conv2d-417           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-418           [64, 1536, 7, 7]           3,072
#             SiLU-419           [64, 1536, 7, 7]               0
#           Conv2d-420           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-421           [64, 1536, 7, 7]           3,072
#             SiLU-422           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-423           [64, 1536, 1, 1]               0
#           Conv2d-424             [64, 64, 1, 1]          98,368
#             SiLU-425             [64, 64, 1, 1]               0
#           Conv2d-426           [64, 1536, 1, 1]          99,840
#          Sigmoid-427           [64, 1536, 1, 1]               0
# SqueezeExcitation-428           [64, 1536, 7, 7]               0
#           Conv2d-429            [64, 256, 7, 7]         393,216
#      BatchNorm2d-430            [64, 256, 7, 7]             512
#  StochasticDepth-431            [64, 256, 7, 7]               0
#           MBConv-432            [64, 256, 7, 7]               0
#           Conv2d-433           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-434           [64, 1536, 7, 7]           3,072
#             SiLU-435           [64, 1536, 7, 7]               0
#           Conv2d-436           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-437           [64, 1536, 7, 7]           3,072
#             SiLU-438           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-439           [64, 1536, 1, 1]               0
#           Conv2d-440             [64, 64, 1, 1]          98,368
#             SiLU-441             [64, 64, 1, 1]               0
#           Conv2d-442           [64, 1536, 1, 1]          99,840
#          Sigmoid-443           [64, 1536, 1, 1]               0
# SqueezeExcitation-444           [64, 1536, 7, 7]               0
#           Conv2d-445            [64, 256, 7, 7]         393,216
#      BatchNorm2d-446            [64, 256, 7, 7]             512
#  StochasticDepth-447            [64, 256, 7, 7]               0
#           MBConv-448            [64, 256, 7, 7]               0
#           Conv2d-449           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-450           [64, 1536, 7, 7]           3,072
#             SiLU-451           [64, 1536, 7, 7]               0
#           Conv2d-452           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-453           [64, 1536, 7, 7]           3,072
#             SiLU-454           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-455           [64, 1536, 1, 1]               0
#           Conv2d-456             [64, 64, 1, 1]          98,368
#             SiLU-457             [64, 64, 1, 1]               0
#           Conv2d-458           [64, 1536, 1, 1]          99,840
#          Sigmoid-459           [64, 1536, 1, 1]               0
# SqueezeExcitation-460           [64, 1536, 7, 7]               0
#           Conv2d-461            [64, 256, 7, 7]         393,216
#      BatchNorm2d-462            [64, 256, 7, 7]             512
#  StochasticDepth-463            [64, 256, 7, 7]               0
#           MBConv-464            [64, 256, 7, 7]               0
#           Conv2d-465           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-466           [64, 1536, 7, 7]           3,072
#             SiLU-467           [64, 1536, 7, 7]               0
#           Conv2d-468           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-469           [64, 1536, 7, 7]           3,072
#             SiLU-470           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-471           [64, 1536, 1, 1]               0
#           Conv2d-472             [64, 64, 1, 1]          98,368
#             SiLU-473             [64, 64, 1, 1]               0
#           Conv2d-474           [64, 1536, 1, 1]          99,840
#          Sigmoid-475           [64, 1536, 1, 1]               0
# SqueezeExcitation-476           [64, 1536, 7, 7]               0
#           Conv2d-477            [64, 256, 7, 7]         393,216
#      BatchNorm2d-478            [64, 256, 7, 7]             512
#  StochasticDepth-479            [64, 256, 7, 7]               0
#           MBConv-480            [64, 256, 7, 7]               0
#           Conv2d-481           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-482           [64, 1536, 7, 7]           3,072
#             SiLU-483           [64, 1536, 7, 7]               0
#           Conv2d-484           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-485           [64, 1536, 7, 7]           3,072
#             SiLU-486           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-487           [64, 1536, 1, 1]               0
#           Conv2d-488             [64, 64, 1, 1]          98,368
#             SiLU-489             [64, 64, 1, 1]               0
#           Conv2d-490           [64, 1536, 1, 1]          99,840
#          Sigmoid-491           [64, 1536, 1, 1]               0
# SqueezeExcitation-492           [64, 1536, 7, 7]               0
#           Conv2d-493            [64, 256, 7, 7]         393,216
#      BatchNorm2d-494            [64, 256, 7, 7]             512
#  StochasticDepth-495            [64, 256, 7, 7]               0
#           MBConv-496            [64, 256, 7, 7]               0
#           Conv2d-497           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-498           [64, 1536, 7, 7]           3,072
#             SiLU-499           [64, 1536, 7, 7]               0
#           Conv2d-500           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-501           [64, 1536, 7, 7]           3,072
#             SiLU-502           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-503           [64, 1536, 1, 1]               0
#           Conv2d-504             [64, 64, 1, 1]          98,368
#             SiLU-505             [64, 64, 1, 1]               0
#           Conv2d-506           [64, 1536, 1, 1]          99,840
#          Sigmoid-507           [64, 1536, 1, 1]               0
# SqueezeExcitation-508           [64, 1536, 7, 7]               0
#           Conv2d-509            [64, 256, 7, 7]         393,216
#      BatchNorm2d-510            [64, 256, 7, 7]             512
#  StochasticDepth-511            [64, 256, 7, 7]               0
#           MBConv-512            [64, 256, 7, 7]               0
#           Conv2d-513           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-514           [64, 1536, 7, 7]           3,072
#             SiLU-515           [64, 1536, 7, 7]               0
#           Conv2d-516           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-517           [64, 1536, 7, 7]           3,072
#             SiLU-518           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-519           [64, 1536, 1, 1]               0
#           Conv2d-520             [64, 64, 1, 1]          98,368
#             SiLU-521             [64, 64, 1, 1]               0
#           Conv2d-522           [64, 1536, 1, 1]          99,840
#          Sigmoid-523           [64, 1536, 1, 1]               0
# SqueezeExcitation-524           [64, 1536, 7, 7]               0
#           Conv2d-525            [64, 256, 7, 7]         393,216
#      BatchNorm2d-526            [64, 256, 7, 7]             512
#  StochasticDepth-527            [64, 256, 7, 7]               0
#           MBConv-528            [64, 256, 7, 7]               0
#           Conv2d-529           [64, 1536, 7, 7]         393,216
#      BatchNorm2d-530           [64, 1536, 7, 7]           3,072
#             SiLU-531           [64, 1536, 7, 7]               0
#           Conv2d-532           [64, 1536, 7, 7]          13,824
#      BatchNorm2d-533           [64, 1536, 7, 7]           3,072
#             SiLU-534           [64, 1536, 7, 7]               0
# AdaptiveAvgPool2d-535           [64, 1536, 1, 1]               0
#           Conv2d-536             [64, 64, 1, 1]          98,368
#             SiLU-537             [64, 64, 1, 1]               0
#           Conv2d-538           [64, 1536, 1, 1]          99,840
#          Sigmoid-539           [64, 1536, 1, 1]               0
# SqueezeExcitation-540           [64, 1536, 7, 7]               0
#           Conv2d-541            [64, 256, 7, 7]         393,216
#      BatchNorm2d-542            [64, 256, 7, 7]             512
#  StochasticDepth-543            [64, 256, 7, 7]               0
#           MBConv-544            [64, 256, 7, 7]               0
#           Conv2d-545           [64, 1280, 7, 7]         327,680
#      BatchNorm2d-546           [64, 1280, 7, 7]           2,560
#             SiLU-547           [64, 1280, 7, 7]               0
# AdaptiveAvgPool2d-548           [64, 1280, 1, 1]               0
#          Dropout-549                 [64, 1280]               0
#           Linear-550                   [64, 10]          12,810
# ================================================================
# Total params: 20,190,298
# Trainable params: 20,190,298
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 36.75
# Forward/backward pass size (MB): 20629.03
# Params size (MB): 77.02
# Estimated Total Size (MB): 20742.80
# ----------------------------------------------------------------

# %%
import torch.optim as optim
from torch.optim import lr_scheduler

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.02, momentum=0.9)
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.5)

# %%
from sklearn.metrics import classification_report
from tqdm.notebook import tqdm


epochs = 20

history_train = {'loss':np.zeros(epochs), 'acc':np.zeros(epochs), 'f1-score':np.zeros(epochs)}
history_val = {'loss':np.zeros(epochs), 'acc':np.zeros(epochs), 'f1-score':np.zeros(epochs)}
min_val_loss = 1e10
PATH = './Animal10-efficientnetV2s.pth'

for epoch in range(epochs):  # loop over the dataset multiple times

    print(f'epoch {epoch + 1} \nTraining ...')
    net.train()
    y_predict = list()
    y_labels = list()
    training_loss = 0.0
    n = 0
    with torch.set_grad_enabled(True):
        for data in tqdm(trainloader):

            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs = inputs.to(device)
            labels = labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # aggregate statistics
            training_loss += loss.item()
            n+=1

            y_labels += list(labels.cpu().numpy())
            y_predict += list(outputs.argmax(dim=1).cpu().numpy())
    scheduler.step()

    # print statistics
    report = classification_report(y_labels, y_predict, digits = 4, output_dict = True)
    acc = report["accuracy"]
    f1 = report["weighted avg"]["f1-score"]
    support = report["weighted avg"]["support"]
    training_loss /= n
    print(f"training loss: {training_loss:.4}, acc: {acc*100:.4}%, f1-score: {f1*100:.4}%, support: {support}" )
    history_train['loss'][epoch] = training_loss
    history_train['acc'][epoch] = acc
    history_train['f1-score'][epoch] = f1

    print('validating ...')
    net.eval()

    optimizer.zero_grad()

    y_predict = list()
    y_labels = list()
    validation_loss = 0.0
    n = 0
    with torch.no_grad():
        for data in tqdm(valloader):
            inputs, labels = data
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = net(inputs)
            loss = criterion(outputs, labels)
            validation_loss += loss.item()

            y_labels += list(labels.cpu().numpy())
            y_predict += list(outputs.argmax(dim=1).cpu().numpy())
            n+=1

    # print statistics
    report = classification_report(y_labels, y_predict, digits = 4, output_dict = True)
    acc = report["accuracy"]
    f1 = report["weighted avg"]["f1-score"]
    support = report["weighted avg"]["support"]
    validation_loss /= n
    print(f"validation loss: {validation_loss:.4}, acc: {acc*100:.4}%, f1-score: {f1*100:.4}%, support: {support}" )
    history_val['loss'][epoch] = validation_loss
    history_val['acc'][epoch] = acc
    history_val['f1-score'][epoch] = f1

    #save min validation loss
    if validation_loss < min_val_loss:
        torch.save(net.state_dict(), PATH)
        min_val_loss = validation_loss

print('Finished Training')
# Out:
# epoch 1
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.9003, acc: 72.71%, f1-score: 72.72%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.7012, acc: 80.33%, f1-score: 80.3%, support: 300
# epoch 2
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.6085, acc: 81.71%, f1-score: 81.7%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.4629, acc: 87.33%, f1-score: 87.39%, support: 300
# epoch 3
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.3733, acc: 87.93%, f1-score: 87.96%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.4703, acc: 86.67%, f1-score: 86.03%, support: 300
# epoch 4
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.2953, acc: 90.57%, f1-score: 90.5%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.3923, acc: 88.0%, f1-score: 88.07%, support: 300
# epoch 5
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.2409, acc: 91.93%, f1-score: 91.91%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.3483, acc: 91.67%, f1-score: 91.69%, support: 300
# epoch 6
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.1803, acc: 94.29%, f1-score: 94.3%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.5061, acc: 86.0%, f1-score: 86.06%, support: 300
# epoch 7
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.1719, acc: 94.57%, f1-score: 94.57%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.3745, acc: 90.0%, f1-score: 90.02%, support: 300
# epoch 8
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.08214, acc: 97.36%, f1-score: 97.36%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.266, acc: 93.67%, f1-score: 93.71%, support: 300
# epoch 9
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.03309, acc: 99.29%, f1-score: 99.29%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.2644, acc: 92.67%, f1-score: 92.7%, support: 300
# epoch 10
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.03836, acc: 98.86%, f1-score: 98.86%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.3122, acc: 92.67%, f1-score: 92.71%, support: 300
# epoch 11
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.02866, acc: 99.0%, f1-score: 99.0%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.251, acc: 93.0%, f1-score: 93.12%, support: 300
# epoch 12
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.02343, acc: 99.21%, f1-score: 99.21%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.246, acc: 94.0%, f1-score: 94.06%, support: 300
# epoch 13
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.02227, acc: 99.0%, f1-score: 99.0%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.2926, acc: 92.33%, f1-score: 92.49%, support: 300
# epoch 14
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.02125, acc: 99.29%, f1-score: 99.29%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.3053, acc: 93.33%, f1-score: 93.43%, support: 300
# epoch 15
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.02468, acc: 99.14%, f1-score: 99.14%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.3118, acc: 94.0%, f1-score: 94.06%, support: 300
# epoch 16
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.01582, acc: 99.57%, f1-score: 99.57%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.2888, acc: 94.0%, f1-score: 94.15%, support: 300
# epoch 17
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.008069, acc: 99.79%, f1-score: 99.79%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.2914, acc: 94.33%, f1-score: 94.38%, support: 300
# epoch 18
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.006506, acc: 99.93%, f1-score: 99.93%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.2645, acc: 93.33%, f1-score: 93.42%, support: 300
# epoch 19
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.007336, acc: 99.86%, f1-score: 99.86%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.279, acc: 94.0%, f1-score: 94.07%, support: 300
# epoch 20
# Training ...
#   0%|          | 0/44 [00:00<?, ?it/s]
# training loss: 0.006083, acc: 99.86%, f1-score: 99.86%, support: 1400
# validating ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# validation loss: 0.3054, acc: 94.67%, f1-score: 94.75%, support: 300
# Finished Training

# %%
min_val_loss
# Out:
# 0.24604353532195092

# %%
fig, axs = plt.subplots(3, figsize= (6,10))
# loss
axs[0].plot(history_train['loss'], label = 'training')
axs[0].plot(history_val['loss'], label = 'validation')
axs[0].set_title("loss")
axs[0].legend()
# acc
axs[1].plot(history_train['acc'], label = 'training')
axs[1].plot(history_val['acc'], label = 'validation')
axs[1].set_title("acc")
axs[1].legend()
# f1-score
axs[2].plot(history_train['f1-score'], label = 'training')
axs[2].plot(history_val['f1-score'], label = 'validation')
axs[2].set_title("f1-score")
axs[2].legend()
plt.show()

# %%
PATH = './Animal10-efficientnetV2s.pth'
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay


print('testing ...')
y_predict = list()
y_labels = list()
test_loss = 0.0
n = 0
with torch.no_grad():
    for data in tqdm(testloader):
        net.eval()
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item()

        y_labels += list(labels.cpu().numpy())
        y_predict += list(outputs.argmax(dim=1).cpu().numpy())
        n+=1

    # print statistics
    test_loss /= n
    print(f"testing loss: {test_loss:.4}" )

    report = classification_report(y_labels, y_predict, digits = 4)
    M = confusion_matrix(y_labels, y_predict)
    print(report)
    disp = ConfusionMatrixDisplay(confusion_matrix=M)
# Out:
# testing ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# testing loss: 0.2137
#               precision    recall  f1-score   support
#
#            0     0.9667    0.9667    0.9667        30
#            1     0.9643    0.9000    0.9310        30
#            2     0.9667    0.9667    0.9667        30
#            3     0.9333    0.9333    0.9333        30
#            4     0.8710    0.9000    0.8852        30
#            5     0.9259    0.8333    0.8772        30
#            6     0.8182    0.9000    0.8571        30
#            7     0.9333    0.9333    0.9333        30
#            8     1.0000    1.0000    1.0000        30
#            9     0.9677    1.0000    0.9836        30
#
#     accuracy                         0.9333       300
#    macro avg     0.9347    0.9333    0.9334       300
# weighted avg     0.9347    0.9333    0.9334       300

# %%
disp.plot()
plt.show()
